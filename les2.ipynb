# %% [markdown]
# Voorbeeld bag of words analyse met naive bayes

# %%
files = ["resources/cancer_abstract.txt","recources/cancer_2_abstract.txt","recources/fibomalgia_2_abstract.txt","recources/fibromalgia_abstract.txt"]

# %% [markdown]
# Eerst het bouwen van de bag of words

# %%
from nlp import file_merger,group_encoder,multi_hot_encoding,frequency_checker,tf_idf_calc
max_tokens = 2000
min_freq = 3
merged_words, len_of_files = file_merger(files)
uncoupled_token_list_of_lists, token_dict = group_encoder(max_tokens,min_freq,merged_words,len_of_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       2 max_tokens = 2000
#       3 min_freq = 3
# ----> 4 merged_words, len_of_files = file_merger(files)
#       5 uncoupled_token_list_of_lists, token_dict = group_encoder(max_tokens,min_freq,merged_words,len_of_files)
#
# File ~/Desktop/bioinformatica/jaar_3/periode_2/modeleren_van_kanker/natural-language-processing/nlp.py:188, in file_merger(list_of_files)
#     185 final_list_of_words = []
#     187 for file_index in range(len(list_of_files)):
# --> 188     words = filereader(list_of_files[file_index])
#     189     list_of_words_per_file.append(words)
#     190     len_of_doc = len(words)
#
# File ~/Desktop/bioinformatica/jaar_3/periode_2/modeleren_van_kanker/natural-language-processing/nlp.py:15, in filereader(file_path)
#       6 """
#       7 Lees een tekstbestand in en splits het in een lijst van woorden.
#       8 Parameters:
#    (...)
#      12     list: lijst met woorden uit het bestand, gescheiden door witruimte.
#      13 """
#      14 # Open en lees het bestand
# ---> 15 with open(file_path, "r", encoding="utf-8") as f:
#      16     text = f.read().lower()
#      17 # Verwijder witruimte aan het begin/eind en splitst de tekst in woorden
#
# FileNotFoundError: [Errno 2] No such file or directory: 'recources/cancer_2_abstract.txt'
